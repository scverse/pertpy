# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ..
# Out:
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/pertpy

# %%
import pertpy as pt
import scanpy as sc

# %%
cd notebooks
# Out:
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/pertpy/notebooks

# %% [markdown]
# ### To load datasets the path has to be communicated

# %%
DATA_DIR = ""

# %% [markdown]
# ### The CRISPR dataset

# %%
adata = pt.datasets.mixscape_vignette_crispr(backup_dir=DATA_DIR)

# %%
sc.set_figure_params(facecolor="white")
sc.pl.umap(adata, color=["replicate", "Phase"])
sc.pl.umap(adata, color=["crispr"], groups=["NT"])
sc.pl.umap(adata, color=["crispr"], groups=["Perturbed"])

# %% [markdown]
# ### The Crohn's disease dataset

# %%
adata_crohn = pt.datasets.mixscape_vignette_crohn(datasetdir=DATA_DIR)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata_crohn
# Out:
# AnnData object with n_obs × n_vars = 127 × 22283
#     obs: 'groups'
